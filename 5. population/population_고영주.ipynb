# %% [markdown]
# # 5-1 목표 명확히 하기, 5-2 인구데이터 확보하고 정리하기

# %% [markdown]
# - 목표 : 인구소멸위기 지역 조사
# - 조사기준 : 한국고용정보원의 <한국 지방소멸에 관한 7가지 분석> 보고서에 나온 기준 사용
# - 인구소멸위기지역 정의 : 65세 이상 노인인구와 20~39세 여성인구를 비교 / 젊은 여성인구가 노인인구의 절반에 미달할 경우
# - 필요 데이터 :
#   1) 지역별 20~30대 여성인구수
#   2) 지역별 65세 이상 노인인구수

# %%
# 데이터 정리 및 시각화를 위한 패키지 import 및 matplot 한글 표시처리

import pandas as pd
import numpy as np

import platform
import matplotlib.pyplot as plt

# %matplotlib inline

path = "c:/Windows/Fonts/malgun.ttf"
from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')    

plt.rcParams['axes.unicode_minus'] = False

# %%
# 인구파일 불러오기
population = pd.read_excel('./05. population_raw_data.xlsx')
population.head()
# Out:
#    행정구역(동읍면)별(1)  행정구역(동읍면)별(2)         항목      2016    2016.1    2016.2  \
# 0  행정구역(동읍면)별(1)  행정구역(동읍면)별(2)         항목         계  20 - 24세  25 - 29세
# 1             전국             소계   총인구수 (명)  51696216   3541061   3217367
# 2            NaN            NaN  남자인구수 (명)  25827594   1877127   1682988
# 3            NaN            NaN  여자인구수 (명)  25868622   1663934   1534379
# 4          서울특별시             소계   총인구수 (명)   9930616    690728    751973
#
#      2016.3    2016.4    2016.5    2016.6    2016.7    2016.8    2016.9  \
# 0  30 - 34세  35 - 39세  65 - 69세  70 - 74세  75 - 79세  80 - 84세  85 - 89세
# 1   3517868   4016272   2237345   1781229   1457890    909130    416164
# 2   1806754   2045265   1072395    806680    600607    319391    113221
# 3   1711114   1971007   1164950    974549    857283    589739    302943
# 4    803507    817467    448956    350580    251961    141649     66067
#
#     2016.10   2016.11 2016.12
# 0  90 - 94세  95 - 99세    100+
# 1    141488     34844   17562
# 2     32695      7658    4137
# 3    108793     27186   13425
# 4     24153      7058    5475

# %%
# 2번째 줄 헤더로 변경
population = pd.read_excel('./05. population_raw_data.xlsx', header = 1)
population.head()
# Out:
#   행정구역(동읍면)별(1) 행정구역(동읍면)별(2)         항목           계   20 - 24세   25 - 29세  \
# 0            전국            소계   총인구수 (명)  51696216.0  3541061.0  3217367.0
# 1           NaN           NaN  남자인구수 (명)  25827594.0  1877127.0  1682988.0
# 2           NaN           NaN  여자인구수 (명)  25868622.0  1663934.0  1534379.0
# 3         서울특별시            소계   총인구수 (명)   9930616.0   690728.0   751973.0
# 4           NaN           NaN  남자인구수 (명)   4876789.0   347534.0   372249.0
#
#    30 - 34세   35 - 39세   65 - 69세   70 - 74세  75 - 79세  80 - 84세  85 - 89세  \
# 0   3517868  4016272.0  2237345.0  1781229.0   1457890  909130.0  416164.0
# 1   1806754  2045265.0  1072395.0   806680.0    600607  319391.0  113221.0
# 2   1711114  1971007.0  1164950.0   974549.0    857283  589739.0  302943.0
# 3    803507   817467.0   448956.0   350580.0    251961  141649.0   66067.0
# 4    402358   410076.0   211568.0   163766.0    112076   54033.0   19595.0
#
#    90 - 94세  95 - 99세     100+
# 0  141488.0     34844  17562.0
# 1   32695.0      7658   4137.0
# 2  108793.0     27186  13425.0
# 3   24153.0      7058   5475.0
# 4    6146.0      1900   1406.0

# %%
# Null값 채워주기 > 같은 열, Null값이 아닌 것 중, 바로 위의 값을 가져옴.
population.fillna(method='pad', inplace=True) 
population.head()
# Out:
#   행정구역(동읍면)별(1) 행정구역(동읍면)별(2)         항목           계   20 - 24세   25 - 29세  \
# 0            전국            소계   총인구수 (명)  51696216.0  3541061.0  3217367.0
# 1            전국            소계  남자인구수 (명)  25827594.0  1877127.0  1682988.0
# 2            전국            소계  여자인구수 (명)  25868622.0  1663934.0  1534379.0
# 3         서울특별시            소계   총인구수 (명)   9930616.0   690728.0   751973.0
# 4         서울특별시            소계  남자인구수 (명)   4876789.0   347534.0   372249.0
#
#    30 - 34세   35 - 39세   65 - 69세   70 - 74세  75 - 79세  80 - 84세  85 - 89세  \
# 0   3517868  4016272.0  2237345.0  1781229.0   1457890  909130.0  416164.0
# 1   1806754  2045265.0  1072395.0   806680.0    600607  319391.0  113221.0
# 2   1711114  1971007.0  1164950.0   974549.0    857283  589739.0  302943.0
# 3    803507   817467.0   448956.0   350580.0    251961  141649.0   66067.0
# 4    402358   410076.0   211568.0   163766.0    112076   54033.0   19595.0
#
#    90 - 94세  95 - 99세     100+
# 0  141488.0     34844  17562.0
# 1   32695.0      7658   4137.0
# 2  108793.0     27186  13425.0
# 3   24153.0      7058   5475.0
# 4    6146.0      1900   1406.0

# %%
# 이름변경
population.rename(columns = {'행정구역(동읍면)별(1)':'광역시도', 
                             '행정구역(동읍면)별(2)':'시도', 
                             '계':'인구수'}, inplace=True)
population.head()
# Out:
#     광역시도  시도         항목         인구수   20 - 24세   25 - 29세  30 - 34세  \
# 0     전국  소계   총인구수 (명)  51696216.0  3541061.0  3217367.0   3517868
# 1     전국  소계  남자인구수 (명)  25827594.0  1877127.0  1682988.0   1806754
# 2     전국  소계  여자인구수 (명)  25868622.0  1663934.0  1534379.0   1711114
# 3  서울특별시  소계   총인구수 (명)   9930616.0   690728.0   751973.0    803507
# 4  서울특별시  소계  남자인구수 (명)   4876789.0   347534.0   372249.0    402358
#
#     35 - 39세   65 - 69세   70 - 74세  75 - 79세  80 - 84세  85 - 89세  90 - 94세  \
# 0  4016272.0  2237345.0  1781229.0   1457890  909130.0  416164.0  141488.0
# 1  2045265.0  1072395.0   806680.0    600607  319391.0  113221.0   32695.0
# 2  1971007.0  1164950.0   974549.0    857283  589739.0  302943.0  108793.0
# 3   817467.0   448956.0   350580.0    251961  141649.0   66067.0   24153.0
# 4   410076.0   211568.0   163766.0    112076   54033.0   19595.0    6146.0
#
#    95 - 99세     100+
# 0     34844  17562.0
# 1      7658   4137.0
# 2     27186  13425.0
# 3      7058   5475.0
# 4      1900   1406.0

# %%
# 데이터 살펴보기
population.시도.value_counts()

# 소계 제외 필요
# 시. 군. 구 레벨 맞지 않음
# Out:
# 소계       54
# 동구       18
# 남구       18
# 중구       18
# 북구       15
# 서구       15
# 강서구       6
# 고성군       6
# 부평구       3
# 철원군       3
# 오산시       3
# 일산서구      3
# 여수시       3
# 은평구       3
# 연수구       3
# 상주시       3
# 창녕군       3
# 담양군       3
# 구례군       3
# 기흥구       3
# 통영시       3
# 남양주시      3
# 신안군       3
# 수지구       3
# 부천시       3
# 장안구       3
# 강릉시       3
# 홍성군       3
# 고창군       3
# 처인구       3
#          ..
# 함평군       3
# 정읍시       3
# 금정구       3
# 부안군       3
# 봉화군       3
# 광진구       3
# 단원구       3
# 무안군       3
# 부산진구      3
# 구미시       3
# 포천시       3
# 사천시       3
# 영주시       3
# 횡성군       3
# 팔달구       3
# 영덕군       3
# 서초구       3
# 금산군       3
# 영광군       3
# 김포시       3
# 대덕구       3
# 광양시       3
# 영월군       3
# 의정부시      3
# 마산회원구     3
# 임실군       3
# 양양군       3
# 목포시       3
# 파주시       3
# 곡성군       3
# Name: 시도, Length: 240, dtype: int64

# %%
# 시도 에서 '소계' 를 제외함
population = population[population.시도 != '소계']
population.head()
# Out:
#      광역시도   시도         항목       인구수  20 - 24세  25 - 29세  30 - 34세  35 - 39세  \
# 6   서울특별시  종로구   총인구수 (명)  152737.0   11379.0   11891.0     10684   10379.0
# 7   서울특별시  종로구  남자인구수 (명)   75201.0    5620.0    6181.0      5387    5034.0
# 8   서울특별시  종로구  여자인구수 (명)   77536.0    5759.0    5710.0      5297    5345.0
# 9   서울특별시   중구   총인구수 (명)  125249.0    8216.0    9529.0     10332   10107.0
# 10  서울특별시   중구  남자인구수 (명)   62204.0    4142.0    4792.0      5192    5221.0
#
#     65 - 69세  70 - 74세  75 - 79세  80 - 84세  85 - 89세  90 - 94세  95 - 99세  \
# 6     7411.0    6636.0      5263    3104.0    1480.0     602.0       234
# 7     3411.0    3009.0      2311    1289.0     506.0     207.0        89
# 8     4000.0    3627.0      2952    1815.0     974.0     395.0       145
# 9     6399.0    5313.0      4127    2502.0    1260.0     469.0       158
# 10    3113.0    2405.0      1752     929.0     414.0     132.0        56
#
#      100+
# 6   220.0
# 7    73.0
# 8   147.0
# 9   160.0
# 10   51.0

# %%
# 컬럼 이름 및 밸류 이름 변경 (축소)
population.is_copy = False   
population.rename(columns = {'항목':'구분'}, inplace=True)
population.loc[population['구분'] == '총인구수 (명)', '구분'] = '합계'
population.loc[population['구분'] == '남자인구수 (명)', '구분'] = '남자'
population.loc[population['구분'] == '여자인구수 (명)', '구분'] = '여자'

population.head()
# Out:
#      광역시도   시도  구분       인구수  20 - 24세  25 - 29세  30 - 34세  35 - 39세  \
# 6   서울특별시  종로구  합계  152737.0   11379.0   11891.0     10684   10379.0
# 7   서울특별시  종로구  남자   75201.0    5620.0    6181.0      5387    5034.0
# 8   서울특별시  종로구  여자   77536.0    5759.0    5710.0      5297    5345.0
# 9   서울특별시   중구  합계  125249.0    8216.0    9529.0     10332   10107.0
# 10  서울특별시   중구  남자   62204.0    4142.0    4792.0      5192    5221.0
#
#     65 - 69세  70 - 74세  75 - 79세  80 - 84세  85 - 89세  90 - 94세  95 - 99세  \
# 6     7411.0    6636.0      5263    3104.0    1480.0     602.0       234
# 7     3411.0    3009.0      2311    1289.0     506.0     207.0        89
# 8     4000.0    3627.0      2952    1815.0     974.0     395.0       145
# 9     6399.0    5313.0      4127    2502.0    1260.0     469.0       158
# 10    3113.0    2405.0      1752     929.0     414.0     132.0        56
#
#      100+
# 6   220.0
# 7    73.0
# 8   147.0
# 9   160.0
# 10   51.0

# %% [markdown]
# # 5-3. 인구 소멸 위기 지역 계산하고 데이터 정리하기

# %%
# 비교기준 20-39세, 65세이상 인구데이터 정리
population['20-39세'] = population['20 - 24세'] + population['25 - 29세'] + \
                        population['30 - 34세'] + population['35 - 39세']
    
population['65세이상'] = population['65 - 69세'] + population['70 - 74세'] + \
                         population['75 - 79세'] + population['80 - 84세'] + \
                         population['85 - 89세'] + population['90 - 94세'] + \
                         population['95 - 99세'] + population['100+']
            
population.head(10)
# Out:
#      광역시도   시도  구분       인구수  20 - 24세  25 - 29세  30 - 34세  35 - 39세  \
# 6   서울특별시  종로구  합계  152737.0   11379.0   11891.0     10684   10379.0
# 7   서울특별시  종로구  남자   75201.0    5620.0    6181.0      5387    5034.0
# 8   서울특별시  종로구  여자   77536.0    5759.0    5710.0      5297    5345.0
# 9   서울특별시   중구  합계  125249.0    8216.0    9529.0     10332   10107.0
# 10  서울특별시   중구  남자   62204.0    4142.0    4792.0      5192    5221.0
# 11  서울특별시   중구  여자   63045.0    4074.0    4737.0      5140    4886.0
# 12  서울특별시  용산구  합계  230241.0   14317.0   16972.0     19032   19127.0
# 13  서울특별시  용산구  남자  111601.0    6937.0    8373.0      9455    9434.0
# 14  서울특별시  용산구  여자  118640.0    7380.0    8599.0      9577    9693.0
# 15  서울특별시  성동구  합계  299259.0   20813.0   23383.0     25507   25979.0
#
#     65 - 69세  70 - 74세  75 - 79세  80 - 84세  85 - 89세  90 - 94세  95 - 99세  \
# 6     7411.0    6636.0      5263    3104.0    1480.0     602.0       234
# 7     3411.0    3009.0      2311    1289.0     506.0     207.0        89
# 8     4000.0    3627.0      2952    1815.0     974.0     395.0       145
# 9     6399.0    5313.0      4127    2502.0    1260.0     469.0       158
# 10    3113.0    2405.0      1752     929.0     414.0     132.0        56
# 11    3286.0    2908.0      2375    1573.0     846.0     337.0       102
# 12   10675.0    9093.0      7477    4553.0    2254.0     916.0       264
# 13    4834.0    3975.0      3094    1739.0     750.0     284.0       102
# 14    5841.0    5118.0      4383    2814.0    1504.0     632.0       162
# 15   12938.0   10734.0      7989    4450.0    1944.0     678.0       209
#
#      100+   20-39세    65세이상
# 6   220.0  44333.0  24950.0
# 7    73.0  22222.0  10895.0
# 8   147.0  22111.0  14055.0
# 9   160.0  38184.0  20388.0
# 10   51.0  19347.0   8852.0
# 11  109.0  18837.0  11536.0
# 12  315.0  69448.0  35547.0
# 13   88.0  34199.0  14866.0
# 14  227.0  35249.0  20681.0
# 15  198.0  95682.0  39140.0

# %%
# 피봇테이블을 활용, 분석에 활용할 컬럼 정리 및 구분 data 정리 (여성 data만 추출)
pop = pd.pivot_table(population,
                    index = ['광역시도','시도'],
                    columns = ['구분'],
                    values = ['인구수','20-39세','65세이상'])
pop.head(10)
# Out:
#            20-39세                      65세이상                         인구수  \
# 구분             남자       여자       합계       남자       여자       합계        남자
# 광역시도 시도
# 강원도  강릉시  26286.0  23098.0  49384.0  15767.0  21912.0  37679.0  106231.0
#      고성군   4494.0   2529.0   7023.0   2900.0   4251.0   7151.0   15899.0
#      동해시  11511.0   9753.0  21264.0   6392.0   8732.0  15124.0   47166.0
#      삼척시   8708.0   7115.0  15823.0   5892.0   8718.0  14610.0   35253.0
#      속초시   9956.0   8752.0  18708.0   5139.0   7613.0  12752.0   40288.0
#      양구군   4368.0   2481.0   6849.0   1650.0   2458.0   4108.0   12918.0
#      양양군   2916.0   2171.0   5087.0   2988.0   3993.0   6981.0   13838.0
#      영월군   4025.0   3134.0   7159.0   4215.0   5700.0   9915.0   20652.0
#      원주시  45755.0  43164.0  88919.0  17384.0  24862.0  42246.0  167854.0
#      인제군   5512.0   3449.0   8961.0   2413.0   3189.0   5602.0   17677.0
#
#
# 구분              여자        합계
# 광역시도 시도
# 강원도  강릉시  107615.0  213846.0
#      고성군   14215.0   30114.0
#      동해시   46131.0   93297.0
#      삼척시   34346.0   69599.0
#      속초시   41505.0   81793.0
#      양구군   11092.0   24010.0
#      양양군   13380.0   27218.0
#      영월군   19421.0   40073.0
#      원주시  170125.0  337979.0
#      인제군   15043.0   32720.0

# %%
# 인구소멸 비율 계산 
pop['소멸비율'] = pop['20-39세','여자'] / (pop['65세이상','합계'] / 2)
pop.head(10)
# Out:
#            20-39세                      65세이상                         인구수  \
# 구분             남자       여자       합계       남자       여자       합계        남자
# 광역시도 시도
# 강원도  강릉시  26286.0  23098.0  49384.0  15767.0  21912.0  37679.0  106231.0
#      고성군   4494.0   2529.0   7023.0   2900.0   4251.0   7151.0   15899.0
#      동해시  11511.0   9753.0  21264.0   6392.0   8732.0  15124.0   47166.0
#      삼척시   8708.0   7115.0  15823.0   5892.0   8718.0  14610.0   35253.0
#      속초시   9956.0   8752.0  18708.0   5139.0   7613.0  12752.0   40288.0
#      양구군   4368.0   2481.0   6849.0   1650.0   2458.0   4108.0   12918.0
#      양양군   2916.0   2171.0   5087.0   2988.0   3993.0   6981.0   13838.0
#      영월군   4025.0   3134.0   7159.0   4215.0   5700.0   9915.0   20652.0
#      원주시  45755.0  43164.0  88919.0  17384.0  24862.0  42246.0  167854.0
#      인제군   5512.0   3449.0   8961.0   2413.0   3189.0   5602.0   17677.0
#
#                                   소멸비율
# 구분              여자        합계
# 광역시도 시도
# 강원도  강릉시  107615.0  213846.0  1.226041
#      고성군   14215.0   30114.0  0.707314
#      동해시   46131.0   93297.0  1.289738
#      삼척시   34346.0   69599.0  0.973990
#      속초시   41505.0   81793.0  1.372647
#      양구군   11092.0   24010.0  1.207887
#      양양군   13380.0   27218.0  0.621974
#      영월군   19421.0   40073.0  0.632173
#      원주시  170125.0  337979.0  2.043460
#      인제군   15043.0   32720.0  1.231346

# %%
# 소멸위기지역 표시
pop['소멸위기지역'] = pop['소멸비율'] < 1.0
pop.head()
# Out:
#            20-39세                      65세이상                         인구수  \
# 구분             남자       여자       합계       남자       여자       합계        남자
# 광역시도 시도
# 강원도  강릉시  26286.0  23098.0  49384.0  15767.0  21912.0  37679.0  106231.0
#      고성군   4494.0   2529.0   7023.0   2900.0   4251.0   7151.0   15899.0
#      동해시  11511.0   9753.0  21264.0   6392.0   8732.0  15124.0   47166.0
#      삼척시   8708.0   7115.0  15823.0   5892.0   8718.0  14610.0   35253.0
#      속초시   9956.0   8752.0  18708.0   5139.0   7613.0  12752.0   40288.0
#
#                                   소멸비율 소멸위기지역
# 구분              여자        합계
# 광역시도 시도
# 강원도  강릉시  107615.0  213846.0  1.226041  False
#      고성군   14215.0   30114.0  0.707314   True
#      동해시   46131.0   93297.0  1.289738  False
#      삼척시   34346.0   69599.0  0.973990   True
#      속초시   41505.0   81793.0  1.372647  False

# %%
#소멸위기지역이 True인 곳 리스트 추출
pop[pop['소멸위기지역']==True].index.get_level_values(1)
# Out:
# Index(['고성군', '삼척시', '양양군', '영월군', '정선군', '평창군', '홍천군', '횡성군', '가평군', '양평군',
#        '연천군', '거창군', '고성군', '남해군', '밀양시', '산청군', '의령군', '창녕군', '하동군', '함안군',
#        '함양군', '합천군', '고령군', '군위군', '문경시', '봉화군', '상주시', '성주군', '영덕군', '영양군',
#        '영주시', '영천시', '예천군', '울릉군', '울진군', '의성군', '청도군', '청송군', '동구', '영도구',
#        '강화군', '옹진군', '강진군', '고흥군', '곡성군', '구례군', '담양군', '보성군', '신안군', '영광군',
#        '영암군', '완도군', '장성군', '장흥군', '진도군', '함평군', '해남군', '화순군', '고창군', '김제시',
#        '남원시', '무주군', '부안군', '순창군', '임실군', '장수군', '정읍시', '진안군', '공주시', '금산군',
#        '논산시', '보령시', '부여군', '서천군', '예산군', '청양군', '태안군', '홍성군', '괴산군', '단양군',
#        '보은군', '영동군', '옥천군'],
#       dtype='object', name='시도')

# %%
# 시각화 data추가를 위한 초기화

pop.reset_index(inplace=True)
pop.head()
# Out:
#    level_0  index 광역시도   시도  20-39세남자  20-39세여자  20-39세합계  65세이상남자  65세이상여자  \
# 0        0      0  강원도  강릉시   26286.0   23098.0   49384.0  15767.0  21912.0
# 1        1      1  강원도  고성군    4494.0    2529.0    7023.0   2900.0   4251.0
# 2        2      2  강원도  동해시   11511.0    9753.0   21264.0   6392.0   8732.0
# 3        3      3  강원도  삼척시    8708.0    7115.0   15823.0   5892.0   8718.0
# 4        4      4  강원도  속초시    9956.0    8752.0   18708.0   5139.0   7613.0
#
#    65세이상합계     인구수남자     인구수여자     인구수합계      소멸비율  소멸위기지역
# 0  37679.0  106231.0  107615.0  213846.0  1.226041   False
# 1   7151.0   15899.0   14215.0   30114.0  0.707314    True
# 2  15124.0   47166.0   46131.0   93297.0  1.289738   False
# 3  14610.0   35253.0   34346.0   69599.0  0.973990    True
# 4  12752.0   40288.0   41505.0   81793.0  1.372647   False

# %%
# 컬럼을 하나로 합치고 병합해제 및 구분 제거
tmp_coloumns = [pop.columns.get_level_values(0)[n]+\
               pop.columns.get_level_values(1)[n]
               for n in range(0,len(pop.columns.get_level_values(0)))]

pop.columns = tmp_coloumns
pop.head()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-73-51db4dd617cd> in <module>()
#       1 # 컬럼을 하나로 합치고 병합해제 및 구분 제거
#       2 tmp_coloumns = [pop.columns.get_level_values(0)[n]+               pop.columns.get_level_values(1)[n]
# ----> 3                for n in range(0,len(pop.columns.get_level_values(0)))]
#       4
#       5 pop.columns = tmp_coloumns
#
# <ipython-input-73-51db4dd617cd> in <listcomp>(.0)
#       1 # 컬럼을 하나로 합치고 병합해제 및 구분 제거
#       2 tmp_coloumns = [pop.columns.get_level_values(0)[n]+               pop.columns.get_level_values(1)[n]
# ----> 3                for n in range(0,len(pop.columns.get_level_values(0)))]
#       4
#       5 pop.columns = tmp_coloumns
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _get_level_values(self, level)
#    2611         """
#    2612
# -> 2613         self._validate_index_level(level)
#    2614         return self
#    2615
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _validate_index_level(self, level)
#    1612                 raise IndexError("Too many levels:"
#    1613                                  " Index has only 1 level, not %d" %
# -> 1614                                  (level + 1))
#    1615         elif level != self.name:
#    1616             raise KeyError('Level %s must be same as name (%s)' %
#
# IndexError: Too many levels: Index has only 1 level, not 2

# %%
pop.head()
# Out:
#    level_0  index 광역시도   시도  20-39세남자  20-39세여자  20-39세합계  65세이상남자  65세이상여자  \
# 0        0      0  강원도  강릉시   26286.0   23098.0   49384.0  15767.0  21912.0
# 1        1      1  강원도  고성군    4494.0    2529.0    7023.0   2900.0   4251.0
# 2        2      2  강원도  동해시   11511.0    9753.0   21264.0   6392.0   8732.0
# 3        3      3  강원도  삼척시    8708.0    7115.0   15823.0   5892.0   8718.0
# 4        4      4  강원도  속초시    9956.0    8752.0   18708.0   5139.0   7613.0
#
#    65세이상합계     인구수남자     인구수여자     인구수합계      소멸비율  소멸위기지역
# 0  37679.0  106231.0  107615.0  213846.0  1.226041   False
# 1   7151.0   15899.0   14215.0   30114.0  0.707314    True
# 2  15124.0   47166.0   46131.0   93297.0  1.289738   False
# 3  14610.0   35253.0   34346.0   69599.0  0.973990    True
# 4  12752.0   40288.0   41505.0   81793.0  1.372647   False
