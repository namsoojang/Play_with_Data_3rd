# %% [markdown]
# # 서울 구별 CCTV 현황 분석
#  - 구별 CCTV 수 파악
#  - 구별 인구수 -> 인구대비 CCTV 비율 --> 평균대비 낮은 구 확인
#  - 시각화
#
#  - ※ Pandas 사용법

# %%
import pandas as pd

# %% [markdown]
# ### 1. CCTV

# %%
# 데이터 불러오기   from   http://data.seoul.go.kr/ 서울 열린데이터광장

# %%
CCTV_Seoul = pd.read_csv('./data/01. CCTV_in_Seoul.csv',  encoding='utf-8')
# 파일경로 위치 확인 필요   ../  Vs  ./ 
CCTV_Seoul.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  2780       1292    430    584    932
# 1  강동구   773        379     99    155    377
# 2  강북구   748        369    120    138    204
# 3  강서구   884        388    258    184     81
# 4  관악구  1496        846    260    390    613

# %%
CCTV_Seoul.columns
# Out:
# Index(['기관명', '소계', '2013년도 이전', '2014년', '2015년', '2016년'], dtype='object')

# %%
CCTV_Seoul.columns = ['구별', '소계', '2013년도 이전', '2014년', '2015년', '2016년']
CCTV_Seoul.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  2780       1292    430    584    932
# 1  강동구   773        379     99    155    377
# 2  강북구   748        369    120    138    204
# 3  강서구   884        388    258    184     81
# 4  관악구  1496        846    260    390    613

# %%
CCTV_Seoul.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  2780       1292    430    584    932
# 1  강동구   773        379     99    155    377
# 2  강북구   748        369    120    138    204
# 3  강서구   884        388    258    184     81
# 4  관악구  1496        846    260    390    613

# %%
# 데이터 살펴보기

# %%
CCTV_Seoul.sort_values(by='소계', ascending=False).head()
# Out:
#      구별    소계  2013년도 이전  2014년  2015년  2016년
# 0   강남구  2780       1292    430    584    932
# 18  양천구  2034       1843    142     30    467
# 14  서초구  1930       1406    157    336    398
# 21  은평구  1873       1138    224    278    468
# 20  용산구  1624       1368    218    112    398

# %%
# CCTV 증가율 넣기... ????

# %%
# 교재버전
CCTV_Seoul['최근증가율'] = (CCTV_Seoul['2016년'] + CCTV_Seoul['2015년'] + \
                        CCTV_Seoul['2014년']) / CCTV_Seoul['2013년도 이전']  * 100
CCTV_Seoul.sort_values(by='최근증가율', ascending=False).head()
# Out:
#      구별    소계  2013년도 이전  2014년  2015년  2016년       최근증가율
# 22  종로구  1002        464    314    211    630  248.922414
# 9   도봉구   485        238    159     42    386  246.638655
# 12  마포구   574        314    118    169    379  212.101911
# 8   노원구  1265        542     57    451    516  188.929889
# 1   강동구   773        379     99    155    377  166.490765

# %%
# 함수로 만들기
def growing(x):
    return (x[3]+x[4]+x[5])/x[2] *100

CCTV_Seoul['최근증가율'] = CCTV_Seoul.apply(growing, axis=1)
CCTV_Seoul.sort_values(by='최근증가율', ascending=False).head()
# Out:
#      구별    소계  2013년도 이전  2014년  2015년  2016년       최근증가율
# 22  종로구  1002        464    314    211    630  248.922414
# 9   도봉구   485        238    159     42    386  246.638655
# 12  마포구   574        314    118    169    379  212.101911
# 8   노원구  1265        542     57    451    516  188.929889
# 1   강동구   773        379     99    155    377  166.490765

# %%
# 람다 함수로 만들기
CCTV_Seoul.apply(lambda x: (x[3]+x[4]+x[5])/x[2] * 100, axis = 1)
CCTV_Seoul.sort_values(by='최근증가율', ascending=False).head()
# Out:
#      구별    소계  2013년도 이전  2014년  2015년  2016년       최근증가율
# 22  종로구  1002        464    314    211    630  248.922414
# 9   도봉구   485        238    159     42    386  246.638655
# 12  마포구   574        314    118    169    379  212.101911
# 8   노원구  1265        542     57    451    516  188.929889
# 1   강동구   773        379     99    155    377  166.490765

# %% [markdown]
# ### 2. 서울시 인구현황

# %%
# 데이터 불러오기

# %%
pop_Seoul = pd.read_excel('./data/01. population_in_Seoul.xls', encoding='utf-8')
pop_Seoul.head()
# Out:
#          기간  자치구       세대        인구     인구.1     인구.2     인구.3     인구.4  \
# 0        기간  자치구       세대        합계       합계       합계      한국인      한국인
# 1        기간  자치구       세대         계       남자       여자        계       남자
# 2  2017.1/4   합계  4202888  10197604  5000005  5197599  9926968  4871560
# 3  2017.1/4  종로구    72654    162820    79675    83145   153589    75611
# 4  2017.1/4   중구    59481    133240    65790    67450   124312    61656
#
#       인구.5    인구.6    인구.7    인구.8  세대당인구  65세이상고령자
# 0      한국인   등록외국인   등록외국인   등록외국인  세대당인구  65세이상고령자
# 1       여자       계      남자      여자  세대당인구  65세이상고령자
# 2  5055408  270636  128445  142191   2.36   1321458
# 3    77978    9231    4064    5167   2.11     25425
# 4    62656    8928    4134    4794   2.09     20764

# %%
pop_Seoul = pd.read_excel('./data/01. population_in_Seoul.xls',
                         header = 2, # 행 번호 header 기준 지정. 기본값 0, 없을경우 None 으로 입력
                         encoding='utf-8')
                        # 교재에서는 parse_cols = 'B,D,G,J,N'  옵션 사용하여 B,D,G,J,N 열만 가지고옴
pop_Seoul.head()
# Out:
#          기간  자치구         세대           계         남자         여자        계.1  \
# 0  2017.1/4   합계  4202888.0  10197604.0  5000005.0  5197599.0  9926968.0
# 1  2017.1/4  종로구    72654.0    162820.0    79675.0    83145.0   153589.0
# 2  2017.1/4   중구    59481.0    133240.0    65790.0    67450.0   124312.0
# 3  2017.1/4  용산구   106544.0    244203.0   119132.0   125071.0   229456.0
# 4  2017.1/4  성동구   130868.0    311244.0   153768.0   157476.0   303380.0
#
#         남자.1       여자.1       계.2      남자.2      여자.2  세대당인구   65세이상고령자
# 0  4871560.0  5055408.0  270636.0  128445.0  142191.0   2.36  1321458.0
# 1    75611.0    77978.0    9231.0    4064.0    5167.0   2.11    25425.0
# 2    61656.0    62656.0    8928.0    4134.0    4794.0   2.09    20764.0
# 3   111167.0   118289.0   14747.0    7965.0    6782.0   2.15    36231.0
# 4   150076.0   153304.0    7864.0    3692.0    4172.0   2.32    39997.0

# %%
pop_Seoul.columns
# Out:
# Index(['기간', '자치구', '세대', '계', '남자', '여자', '계.1', '남자.1', '여자.1', '계.2',
#        '남자.2', '여자.2', '세대당인구', '65세이상고령자'],
#       dtype='object')

# %%
# 구별 인구수 / 한국인수 / 외국인수 / 고령자수 만 가져오기

# pd.loc[행이름,열이름]  Vs  pd.iloc[행index, 열index]

Check = pop_Seoul.loc[:,['자치구','계','계.1','계.2','65세이상고령자']]
# Check = pop_Seoul.iloc[:,[1,3,6,9,-1]]

Check.head()
# Out:
#    자치구           계        계.1       계.2   65세이상고령자
# 0   합계  10197604.0  9926968.0  270636.0  1321458.0
# 1  종로구    162820.0   153589.0    9231.0    25425.0
# 2   중구    133240.0   124312.0    8928.0    20764.0
# 3  용산구    244203.0   229456.0   14747.0    36231.0
# 4  성동구    311244.0   303380.0    7864.0    39997.0

# %%
pop_Seoul = pop_Seoul.loc[:,['자치구','계','계.1','계.2','65세이상고령자']]
pop_Seoul.columns = ['구별','인구수','한국인','외국인','고령자']

# pop_Seoul.rename(columns={pop_Seoul.columns[0] : '구별', 
#                           pop_Seoul.columns[1] : '인구수', 
#                           pop_Seoul.columns[2] : '한국인', 
#                           pop_Seoul.columns[3] : '외국인', 
#                           pop_Seoul.columns[4] : '고령자'}, inplace=True)


pop_Seoul.head()
# Out:
#     구별         인구수        한국인       외국인        고령자
# 0   합계  10197604.0  9926968.0  270636.0  1321458.0
# 1  종로구    162820.0   153589.0    9231.0    25425.0
# 2   중구    133240.0   124312.0    8928.0    20764.0
# 3  용산구    244203.0   229456.0   14747.0    36231.0
# 4  성동구    311244.0   303380.0    7864.0    39997.0

# %%
# 살펴보기

# %%
pop_Seoul.drop(0, inplace=True)  # 0번 행렬 "합계" 삭제하기
pop_Seoul.head()
# Out:
#     구별       인구수       한국인      외국인      고령자
# 1  종로구  162820.0  153589.0   9231.0  25425.0
# 2   중구  133240.0  124312.0   8928.0  20764.0
# 3  용산구  244203.0  229456.0  14747.0  36231.0
# 4  성동구  311244.0  303380.0   7864.0  39997.0
# 5  광진구  372164.0  357211.0  14953.0  42214.0

# %%
? pop_Seoul.drop

# %%
pop_Seoul['구별'].unique()
# Out:
# array(['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구',
#        '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구',
#        '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구', nan],
#       dtype=object)

# %%
pop_Seoul['구별'].notnull()
# Out:
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26    False
# Name: 구별, dtype: bool

# %%
# NA 데이터 삭제하기

# dropna로 선택
pop_Seoul.dropna(subset=['구별'], axis=0, inplace = True)    # axis = 0  행,  axis = 1  열

#notnull로 선택
pop_Seoul= pop_Seoul[pop_Seoul['구별'].notnull()]    # DataFrame[True/False]

# 교재 방법
# pop_Seoul.drop([26], inplace=True)
pop_Seoul.head()
# Out:
#     구별       인구수       한국인      외국인      고령자
# 1  종로구  162820.0  153589.0   9231.0  25425.0
# 2   중구  133240.0  124312.0   8928.0  20764.0
# 3  용산구  244203.0  229456.0  14747.0  36231.0
# 4  성동구  311244.0  303380.0   7864.0  39997.0
# 5  광진구  372164.0  357211.0  14953.0  42214.0

# %%
pop_Seoul[['구별','인구수']]
pop_Seoul.loc[:,['구별','인구수']]
# Out:
#       구별       인구수
# 1    종로구  162820.0
# 2     중구  133240.0
# 3    용산구  244203.0
# 4    성동구  311244.0
# 5    광진구  372164.0
# 6   동대문구  369496.0
# 7    중랑구  414503.0
# 8    성북구  461260.0
# 9    강북구  330192.0
# 10   도봉구  348646.0
# 11   노원구  569384.0
# 12   은평구  494388.0
# 13  서대문구  327163.0
# 14   마포구  389649.0
# 15   양천구  479978.0
# 16   강서구  603772.0
# 17   구로구  447874.0
# 18   금천구  255082.0
# 19  영등포구  402985.0
# 20   동작구  412520.0
# 21   관악구  525515.0
# 22   서초구  450310.0
# 23   강남구  570500.0
# 24   송파구  667483.0
# 25   강동구  453233.0

# %%
pop_Seoul['외국인비율'] = pop_Seoul['외국인'] / pop_Seoul['인구수'] *100
pop_Seoul['고령자비율'] = pop_Seoul['고령자'] / pop_Seoul['인구수'] *100
pop_Seoul.head()
# Out:
#     구별       인구수       한국인      외국인      고령자     외국인비율      고령자비율
# 1  종로구  162820.0  153589.0   9231.0  25425.0  5.669451  15.615404
# 2   중구  133240.0  124312.0   8928.0  20764.0  6.700690  15.583909
# 3  용산구  244203.0  229456.0  14747.0  36231.0  6.038828  14.836427
# 4  성동구  311244.0  303380.0   7864.0  39997.0  2.526635  12.850689
# 5  광진구  372164.0  357211.0  14953.0  42214.0  4.017852  11.342849

# %% [markdown]
# ### 3. CCTV 데이터 + 인구데이터

# %%
#데이터 합치기
data_result = pd.merge(CCTV_Seoul, pop_Seoul, on='구별')
data_result.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년       최근증가율       인구수       한국인  \
# 0  강남구  2780       1292    430    584    932  150.619195  570500.0  565550.0
# 1  강동구   773        379     99    155    377  166.490765  453233.0  449019.0
# 2  강북구   748        369    120    138    204  125.203252  330192.0  326686.0
# 3  강서구   884        388    258    184     81  134.793814  603772.0  597248.0
# 4  관악구  1496        846    260    390    613  149.290780  525515.0  507203.0
#
#        외국인      고령자     외국인비율      고령자비율
# 0   4950.0  63167.0  0.867660  11.072217
# 1   4214.0  54622.0  0.929765  12.051638
# 2   3506.0  54813.0  1.061806  16.600342
# 3   6524.0  72548.0  1.080540  12.015794
# 4  18312.0  68082.0  3.484582  12.955291

# %%
# 불필요할 한 열 삭제
data_result.columns
# Out:
# Index(['구별', '소계', '2013년도 이전', '2014년', '2015년', '2016년', '최근증가율', '인구수',
#        '한국인', '외국인', '고령자', '외국인비율', '고령자비율'],
#       dtype='object')

# %%
data_result = data_result[['구별', '소계', '최근증가율', '인구수', '한국인', '외국인', '고령자', '외국인비율', '고령자비율']]
# del 활용 가능:  del data_result[열 이름]

# %%
data_result.head()
# Out:
#     구별    소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 0  강남구  2780  150.619195  570500.0  565550.0   4950.0  63167.0  0.867660
# 1  강동구   773  166.490765  453233.0  449019.0   4214.0  54622.0  0.929765
# 2  강북구   748  125.203252  330192.0  326686.0   3506.0  54813.0  1.061806
# 3  강서구   884  134.793814  603772.0  597248.0   6524.0  72548.0  1.080540
# 4  관악구  1496  149.290780  525515.0  507203.0  18312.0  68082.0  3.484582
#
#        고령자비율
# 0  11.072217
# 1  12.051638
# 2  16.600342
# 3  12.015794
# 4  12.955291

# %%
# index 만들어주기

# %%
# index 값 지정 --> 추가로 생성
data_result.index = data_result['구별']  # '구별' 값과 동일하게 인덱스 변경
data_result.head()
# Out:
#       구별    소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 구별
# 강남구  강남구  2780  150.619195  570500.0  565550.0   4950.0  63167.0  0.867660
# 강동구  강동구   773  166.490765  453233.0  449019.0   4214.0  54622.0  0.929765
# 강북구  강북구   748  125.203252  330192.0  326686.0   3506.0  54813.0  1.061806
# 강서구  강서구   884  134.793814  603772.0  597248.0   6524.0  72548.0  1.080540
# 관악구  관악구  1496  149.290780  525515.0  507203.0  18312.0  68082.0  3.484582
#
#          고령자비율
# 구별
# 강남구  11.072217
# 강동구  12.051638
# 강북구  16.600342
# 강서구  12.015794
# 관악구  12.955291

# %%
# set_index: 기존 column 값 --> index 로 지정
data_result.set_index('구별', inplace=True)    # '구별' 열을 인덱스로 설정
data_result.head()
# Out:
#        소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 구별
# 강남구  2780  150.619195  570500.0  565550.0   4950.0  63167.0  0.867660
# 강동구   773  166.490765  453233.0  449019.0   4214.0  54622.0  0.929765
# 강북구   748  125.203252  330192.0  326686.0   3506.0  54813.0  1.061806
# 강서구   884  134.793814  603772.0  597248.0   6524.0  72548.0  1.080540
# 관악구  1496  149.290780  525515.0  507203.0  18312.0  68082.0  3.484582
#
#          고령자비율
# 구별
# 강남구  11.072217
# 강동구  12.051638
# 강북구  16.600342
# 강서구  12.015794
# 관악구  12.955291

# %%
# 변수간 관계 살펴보기: 상관관계

# %%
import numpy as np

# %%
# numpy 활용하기
print("고령자비율 Vs CCTV\n", np.corrcoef(data_result['고령자비율'],data_result['소계']))
print("\n\n외국인비율 Vs CCTV\n", np.corrcoef(data_result['외국인비율'],data_result['소계']))
print("\n\n인구수 Vs CCTV\n", np.corrcoef(data_result['인구수'],data_result['소계']))
# Out:
# 고령자비율 Vs CCTV
#  [[ 1.         -0.28078554]
#  [-0.28078554  1.        ]]
#
#
# 외국인비율 Vs CCTV
#  [[ 1.         -0.13607433]
#  [-0.13607433  1.        ]]
#
#
# 인구수 Vs CCTV
#  [[1.         0.30634228]
#  [0.30634228 1.        ]]

# %%
# Pandas 에서 변수간 상관계수 구하기  (연속형만 가능)
data_result.corr()
# Out:
#              소계     최근증가율       인구수       한국인       외국인       고령자     외국인비율  \
# 소계     1.000000 -0.343016  0.306342  0.304287 -0.023786  0.255196 -0.136074
# 최근증가율 -0.343016  1.000000 -0.093068 -0.082511 -0.150463 -0.070969 -0.044042
# 인구수    0.306342 -0.093068  1.000000  0.998061 -0.153371  0.932667 -0.591939
# 한국인    0.304287 -0.082511  0.998061  1.000000 -0.214576  0.931636 -0.637911
# 외국인   -0.023786 -0.150463 -0.153371 -0.214576  1.000000 -0.155381  0.838904
# 고령자    0.255196 -0.070969  0.932667  0.931636 -0.155381  1.000000 -0.606088
# 외국인비율 -0.136074 -0.044042 -0.591939 -0.637911  0.838904 -0.606088  1.000000
# 고령자비율 -0.280786  0.185089 -0.669462 -0.660812 -0.014055 -0.380468  0.267348
#
#           고령자비율
# 소계    -0.280786
# 최근증가율  0.185089
# 인구수   -0.669462
# 한국인   -0.660812
# 외국인   -0.014055
# 고령자   -0.380468
# 외국인비율  0.267348
# 고령자비율  1.000000

# %%
# 인구수와 CCTV 상관관계 있음?

# %%
data_result.sort_values(by='인구수', ascending=False).head(10)
# Out:
#        소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 구별
# 송파구   618  104.347826  667483.0  660584.0   6899.0  72506.0  1.033584
# 강서구   884  134.793814  603772.0  597248.0   6524.0  72548.0  1.080540
# 강남구  2780  150.619195  570500.0  565550.0   4950.0  63167.0  0.867660
# 노원구  1265  188.929889  569384.0  565565.0   3819.0  71941.0  0.670725
# 관악구  1496  149.290780  525515.0  507203.0  18312.0  68082.0  3.484582
# 은평구  1873   85.237258  494388.0  489943.0   4445.0  72334.0  0.899091
# 양천구  2034   34.671731  479978.0  475949.0   4029.0  52975.0  0.839413
# 성북구  1464   63.627354  461260.0  449773.0  11487.0  64692.0  2.490353
# 강동구   773  166.490765  453233.0  449019.0   4214.0  54622.0  0.929765
# 서초구  1930   63.371266  450310.0  445994.0   4316.0  51733.0  0.958451
#
#          고령자비율
# 구별
# 송파구  10.862599
# 강서구  12.015794
# 강남구  11.072217
# 노원구  12.634883
# 관악구  12.955291
# 은평구  14.631019
# 양천구  11.036964
# 성북구  14.025062
# 강동구  12.051638
# 서초구  11.488308

# %% [markdown]
# ### 4. 시각화

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
data_result['소계'].plot(kind='barh',grid=True, figsize=(10,10))

# %%
data_result['소계'].sort_values().plot(kind='barh',grid=True, figsize=(10,10))

# %%
# 인구대비 CCTV비율

data_result['CCTV비율'] = data_result.소계 / data_result.인구수*100   # 비율???  기준 시점 다름......
data_result.CCTV비율.sort_values().plot(kind='barh', grid=True, figsize=(10,10))

# %%
? plt.plot

# %%
# scatter 
plt.scatter(data_result.인구수, data_result.소계, s=50)
plt.xlabel('인구수')
plt.ylabel('CCTV')
plt.grid()

# %%
# 1차원 회귀식 만들기
fp1 = np.polyfit(data_result.인구수, data_result.소계, 1)
fp1
# Out:
# array([1.30916415e-03, 6.45066497e+02])

# %%
f1 = np.poly1d(fp1)
fx = np.linspace(100000,700000,100)

# %%
#  np.linspace(100000,700000,100)

# %%
plt.scatter(data_result.인구수, data_result.소계, s=50)
plt.plot(fx,f1(fx), ls='dashed', lw=3, color='g')
plt.xlabel('인구수')
plt.ylabel('CCTV')
plt.grid()

# %% [markdown]
# # (추가) 1인가구수 추가

# %%
#1인가구 파일 불러오기

# %%
Seoul_1P = pd.read_csv('./data/01. people_in_seoul_2016.csv',  encoding='euc-kr')
# 파일경로 위치 확인 필요   ../  Vs  ./ 
Seoul_1P.head()
# Out:
#     구별  1인_전체  1인_20세미만  1인_20대  1인_30대  1인_40대  1인_50대  1인_60대  1인_70대  \
# 0  종로구  22835       526    6520    4209    3130    3081    2451    1961
# 1   중구  19671       567    4582    3735    3036    2873    2348    1731
# 2  용산구  31641       250    6699    7507    5375    4192    3422    2730
# 3  성동구  37074       878    9982    7625    5657    5109    3697    2869
# 4  광진구  53169       805   16065   13225    7583    6570    4529    3032
#
#    1인_80세 이상
# 0        957
# 1        799
# 2       1466
# 3       1257
# 4       1360

# %%
# 서울인구, CCTV수 다시 불러오기
data_set = pd.merge(CCTV_Seoul, pop_Seoul, on='구별')
data_set.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년       최근증가율       인구수       한국인  \
# 0  강남구  2780       1292    430    584    932  150.619195  570500.0  565550.0
# 1  강동구   773        379     99    155    377  166.490765  453233.0  449019.0
# 2  강북구   748        369    120    138    204  125.203252  330192.0  326686.0
# 3  강서구   884        388    258    184     81  134.793814  603772.0  597248.0
# 4  관악구  1496        846    260    390    613  149.290780  525515.0  507203.0
#
#        외국인      고령자     외국인비율      고령자비율
# 0   4950.0  63167.0  0.867660  11.072217
# 1   4214.0  54622.0  0.929765  12.051638
# 2   3506.0  54813.0  1.061806  16.600342
# 3   6524.0  72548.0  1.080540  12.015794
# 4  18312.0  68082.0  3.484582  12.955291

# %%
# 데이터셋(인구+cctv+1인가구) 만들기
data_set2 = pd.merge(data_set, Seoul_1P, on='구별')
data_set2.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년       최근증가율       인구수       한국인  \
# 0  강남구  2780       1292    430    584    932  150.619195  570500.0  565550.0
# 1  강동구   773        379     99    155    377  166.490765  453233.0  449019.0
# 2  강북구   748        369    120    138    204  125.203252  330192.0  326686.0
# 3  강서구   884        388    258    184     81  134.793814  603772.0  597248.0
# 4  관악구  1496        846    260    390    613  149.290780  525515.0  507203.0
#
#        외국인    ...          고령자비율   1인_전체  1인_20세미만  1인_20대  1인_30대  1인_40대  \
# 0   4950.0    ...      11.072217   61998       572   12942   20651   10522
# 1   4214.0    ...      12.051638   39469       158    5640    8794    6871
# 2   3506.0    ...      16.600342   36668       199    4933    6150    5893
# 3   6524.0    ...      12.015794   60988       279   11257   15160    9540
# 4  18312.0    ...      12.955291  103972      1053   38095   28451   12792
#
#    1인_50대  1인_60대  1인_70대  1인_80세 이상
# 0    6494    5395    3534       1888
# 1    7121    5837    3364       1684
# 2    6759    6119    4697       1918
# 3    8921    7896    5245       2690
# 4    9262    7280    5097       1942
#
# [5 rows x 22 columns]

# %%
# 불필요할 한 열 삭제
data_set2.columns
# Out:
# Index(['구별', '소계', '2013년도 이전', '2014년', '2015년', '2016년', '최근증가율', '인구수',
#        '한국인', '외국인', '고령자', '외국인비율', '고령자비율', '1인_전체', '1인_20세미만', '1인_20대',
#        '1인_30대', '1인_40대', '1인_50대', '1인_60대', '1인_70대', '1인_80세 이상'],
#       dtype='object')

# %%
data_set2 = data_set2[['구별', '소계', '최근증가율', '2016년', '인구수', '한국인', '외국인', '고령자', '외국인비율', '고령자비율', '1인_전체']]
# del 활용 가능:  del data_result[열 이름]

# %%
data_set2.head()
# Out:
#     구별    소계       최근증가율  2016년       인구수       한국인      외국인      고령자  \
# 0  강남구  2780  150.619195    932  570500.0  565550.0   4950.0  63167.0
# 1  강동구   773  166.490765    377  453233.0  449019.0   4214.0  54622.0
# 2  강북구   748  125.203252    204  330192.0  326686.0   3506.0  54813.0
# 3  강서구   884  134.793814     81  603772.0  597248.0   6524.0  72548.0
# 4  관악구  1496  149.290780    613  525515.0  507203.0  18312.0  68082.0
#
#       외국인비율      고령자비율   1인_전체      CCTV
# 0  0.867660  11.072217   61998  0.487292
# 1  0.929765  12.051638   39469  0.170552
# 2  1.061806  16.600342   36668  0.226535
# 3  1.080540  12.015794   60988  0.146413
# 4  3.484582  12.955291  103972  0.284673

# %%
# Pandas 에서 변수간 상관계수 구하기  (연속형만 가능)
data_set2.corr()
# Out:
#              소계     최근증가율     2016년       인구수       한국인       외국인       고령자  \
# 소계     1.000000 -0.343016  0.593398  0.306342  0.304287 -0.023786  0.255196
# 최근증가율 -0.343016  1.000000  0.312985 -0.093068 -0.082511 -0.150463 -0.070969
# 2016년  0.593398  0.312985  1.000000  0.144959  0.145966 -0.042688  0.065784
# 인구수    0.306342 -0.093068  0.144959  1.000000  0.998061 -0.153371  0.932667
# 한국인    0.304287 -0.082511  0.145966  0.998061  1.000000 -0.214576  0.931636
# 외국인   -0.023786 -0.150463 -0.042688 -0.153371 -0.214576  1.000000 -0.155381
# 고령자    0.255196 -0.070969  0.065784  0.932667  0.931636 -0.155381  1.000000
# 외국인비율 -0.136074 -0.044042 -0.020160 -0.591939 -0.637911  0.838904 -0.606088
# 고령자비율 -0.280786  0.185089 -0.139364 -0.669462 -0.660812 -0.014055 -0.380468
# 1인_전체  0.195238 -0.024875  0.187747  0.637027  0.616913  0.202029  0.646117
#
#           외국인비율     고령자비율     1인_전체
# 소계    -0.136074 -0.280786  0.195238
# 최근증가율 -0.044042  0.185089 -0.024875
# 2016년 -0.020160 -0.139364  0.187747
# 인구수   -0.591939 -0.669462  0.637027
# 한국인   -0.637911 -0.660812  0.616913
# 외국인    0.838904 -0.014055  0.202029
# 고령자   -0.606088 -0.380468  0.646117
# 외국인비율  1.000000  0.267348 -0.182963
# 고령자비율  0.267348  1.000000 -0.371396
# 1인_전체 -0.182963 -0.371396  1.000000

# %%
# CCTV수와 1인가구수 상관관계 있음?
data_set2.sort_values(by='1인_전체', ascending=False).head(10)
# Out:
#       구별    소계       최근증가율  2016년       인구수       한국인      외국인      고령자  \
# 4    관악구  1496  149.290780    613  525515.0  507203.0  18312.0  68082.0
# 0    강남구  2780  150.619195    932  570500.0  565550.0   4950.0  63167.0
# 3    강서구   884  134.793814     81  603772.0  597248.0   6524.0  72548.0
# 17   송파구   618  104.347826    463  667483.0  660584.0   6899.0  72506.0
# 16   성북구  1464   63.627354    204  461260.0  449773.0  11487.0  64692.0
# 12   마포구   574  212.101911    379  389649.0  378566.0  11083.0  48765.0
# 5    광진구   707   53.228621    174  372164.0  357211.0  14953.0  42214.0
# 11   동작구  1091  139.338235    314  412520.0  400456.0  12064.0  56013.0
# 10  동대문구  1294   74.766355    579  369496.0  354079.0  15417.0  54173.0
# 19  영등포구   904  157.979798    373  402985.0  368072.0  34913.0  52413.0
#
#        외국인비율      고령자비율   1인_전체
# 4   3.484582  12.955291  103972
# 0   0.867660  11.072217   61998
# 3   1.080540  12.015794   60988
# 17  1.033584  10.862599   54409
# 16  2.490353  14.025062   54117
# 12  2.844355  12.515110   53382
# 5   4.017852  11.342849   53169
# 11  2.924464  13.578251   52954
# 10  4.172440  14.661322   52650
# 19  8.663598  13.006191   49453

# %%
# 시각화
import matplotlib.pyplot as plt
# %matplotlib inline

import platform

# %%
from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
data_set2['1인_전체'].plot(kind='barh',grid=True, figsize=(10,10))

# %%
data_set2['1인_전체'].plot(kind='barh',grid=True, figsize=(10,10))

data_set2['1인_전체'].sort_values().plot(kind='barh',grid=True, figsize=(10,10))
